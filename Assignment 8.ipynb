# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1) create first array "overs" with 4 elements
# 5,10,15,20
# create another array "runs_scored" with 4 elements and store
# no.of runs scored at the end of each over
# e.g.  40 runs at the end of 5th over , 75 runs at the end of 10th over etc.
#
# now create a line plot to show the relationship between "overs" and "runs_scored"

# %%
overs = np.arange(1,21)
ind = 7,23,35,47,63,82,98,113,122,152,166,172,190,201,213,234,252,267,282,297
ban = 5,17,35,39,59,59,64,77,86,94,107,112,119,126,133,135,138,150,156,164
ind_wickets = [2,14,15,19,19]
ban_wickets = [1,4,6,12,15,17,18]

plt.scatter(ind_wickets, [ind[i - 1] for i in ind_wickets], marker='o', s=20, label="India Wickets")

# Scatter plot to show where wickets fell (for Bangladesh)
plt.scatter(ban_wickets, [ban[i - 1] for i in ban_wickets], marker='o', s=20, label="Bangladesh Wickets")

# Adding titles and labels
plt.plot(overs,ind,linestyle=':',color='blue')
plt.plot(overs,ban,linestyle=':',color='g')

# %% [markdown]
# #### 2) create a Bar plot to show how many people like "Action","Romance","Comedy" or "Drama" movies.

# %%
genre = ['Action','Romance','Comedy','Drama']
nop = [19,14,15,10]
plt.bar(genre,nop)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# #### 3) create a piechart to show popularity of various modules (Java,Python etc.)

# %%
modules = ['Java','Python','C#','R','DSA']
pop = [140,160,40,35,100]
plt.pie(pop,labels=modules,autopct='%0.1f%%')
plt.show()
