# %% [markdown]
# # Pillow
# ##### PIL is the Python Imaging Library which provides the python interpreter with image editing capabilities.

# %%
from PIL import Image

# %%
img=Image.open("Balls.jpg")
print(img.height)
print(img.width)
print(img.size)
print(img.format)
img.show()
# Out:
# 600
# 800
# (800, 600)
# JPEG

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
# Resize an image

from PIL import Image

img=Image.open("Ghost.jpg")
new_size=(400,400)    #  can reduce but cannot increase the size of original image
img.thumbnail(new_size)
img.save('Ghost2.jpg')

print("Done")
# Out:
# Done

# %%
# Rotating an image

from PIL import Image

img=Image.open("3_idiots.jpg")
img.rotate(120).show()

print("Done")
# Out:
# Done

# %%
from PIL import Image

img=Image.open("3_idiots.jpg")
img.rotate(270).save('temp.jpg')
img1=Image.open("temp.jpg")
img1.show()
print("Done")
# Out:
# Done

# %%
# Cropping an image

from PIL import Image

img=Image.open("Ghost.jpg")
area=(180,40,560,210)
img.crop(area).show()

print("Done")
# Out:
# Done

# %%
# Creating new image
from PIL import Image,ImageDraw,ImageFont

size=height,width=(300,300)
img=Image.new("RGB",size,"red")
draw=ImageDraw.Draw(img)
myfont=ImageFont.truetype("arial.ttf",30)
points=100,100
title="All the best"
draw.text(points, title,"white",font=myfont)
img.show()
print("Done")
# Out:
# Done

# %%
# Filtering Images

from PIL import Image,ImageFilter

img=Image.open("Ghost.jpg")
img.filter(ImageFilter.BLUR()).show()
#img.filter(ImageFilter.EDGE_ENHANCE()).show()
#img.filter(ImageFilter.EMBOSS()).show()
#img.filter(ImageFilter.CONTOUR()).show()

# %%
# Writing text on the image

from PIL import Image,ImageDraw,ImageFont

img=Image.open("abhi.jpg")
draw=ImageDraw.Draw(img)
myfont=ImageFont.truetype("arial.ttf",15)
points=10,250
title="Ek Rapta mara na sadak pai hagta phirega"
draw.text(points, title,"red",font=myfont)
img.show()

# %%
# flip the image and merge the images
from PIL import Image
  
# Open an already existing image and create image object  
sidha_image = Image.open("Image_2.jpg")  
  
# perform a flip of left and right  
ultaImage = sidha_image.transpose(Image.Transpose.FLIP_TOP_BOTTOM)

# display the original image  
sidha_image.show()  
  
# display the horizontal flipped image  
ultaImage.show()  
size=height,width=(800,800)
new_image=Image.new("RGB",size,"red")
new_image.paste(sidha_image,(0,0))
new_image.paste(ultaImage,(400,0))
new_image.show()

# %% [markdown]
# # Exception Handling
# ##### An exception is an event, which occurs during the execution of a program, that interrupts the normal flow of the program's instructions.

# %%
var=5
print(var/0)
print("done")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[77], line 2
#       1 var=5
# ----> 2 print(var/0)
#       3 print("done")
#
# ZeroDivisionError: division by zero

# %%
try:
    print(5/0)
except ZeroDivisionError:
    print("You can't devide any number by 0")
print("done")
# Out:
# You can't devide any number by 0
# done

# %%
print("Let's open a file")
open("sample1.txt","r")
print("done")
# Out:
# Let's open a file
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[83], line 2
#       1 print("Let's open a file")
# ----> 2 open("sample1.txt","r")
#       3 print("done")
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample1.txt'

# %%
print("Let's open a file")
try:
    open("sample1.txt","r")
except FileNotFoundError:
    print("File not found")
print("done")
# Out:
# Let's open a file
# File not found
# done

# %%
def fun():
	try:
		f=open("d:\\FileDemo1.java","r")
	except FileNotFoundError:
		print("File not Found")
	finally:
		print("I will always execute")
	print("Done")
fun()
# Out:
# File not Found
# I will always execute
# Done

# %%
def fun():
	try:
		f=open("d:\\FileDemo1.java","r")
	finally:
		print("I will always execute")
	print("Done")
fun()
# Out:
# I will always execute
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[93], line 7
#       5 		print("I will always execute")
#       6 	print("Done")
# ----> 7 fun()
#
# Cell In[93], line 3, in fun()
#       1 def fun():
#       2 	try:
# ----> 3 		f=open("d:\\FileDemo1.java","r")
#       4 	finally:
#       5 		print("I will always execute")
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'd:\\FileDemo1.java'

# %%
# generic catch block

def fun():
	try:
		f=open("d:\\FileDemo.java","r")
		for content in f:
			print(content)
		var=10/0
	except Exception as e:
		print("some other error\t",e.__str__())
		print("some other error\t",e)
	print("Done")
fun()
# Out:
# some other error	 [Errno 2] No such file or directory: 'd:\\FileDemo.java'
# some other error	 [Errno 2] No such file or directory: 'd:\\FileDemo.java'
# Done

# %%
def fun():
	try:
		f=open("Book1.csv","r")
		for content in f:
			print(content)
		var=10/0
	except Exception as e:
		print("some other error\t",e)
	except ZeroDivisionError as z:
		print("error is\t",z)
	print("Done")
fun()
# Out:
# name,age,address
#
# Rohit,35,mumbai
#
# Virat,36,delhi
#
# Sachin,50,mumbai
#
# Ashwin,38,chennai
#
# Bumrah,29,mumbai
#
# Shami,33,banglore
#
# Yuvraj,43,delhi
#
# Dhoni,43,delhi
#
# Sky,29,mumbai
#
# Umesh,30,banglore
#
# some other error	 division by zero
# Done

# %%
def fun():
	try:
		f=open("myfile.json","r")
		for content in f:
			print(content)
		var=10/0
	except ZeroDivisionError as z:
		print("error is\t",z)
	except Exception as e:
		print("some other error\t",e)
	print("Done")
fun()
# Out:
# {
#
#   "Duration":{
#
#     "0":60,
#
#     "1":60,
#
#     "2":60,
#
#     "3":45,
#
#     "4":45,
#
#     "5":60,
#
#     "6":60,
#
#     "7":45,
#
#     "8":30,
#
#     "9":60,
#
#     "10":60,
#
#     "11":60,
#
#     "12":60,
#
#     "13":60,
#
#     "14":60,
#
#     "15":60,
#
#     "16":60,
#
#     "17":45,
#
#     "18":60,
#
#     "19":45,
#
#     "20":60,
#
#     "21":45,
#
#     "22":60,
#
#     "23":45,
#
#     "24":60,
#
#     "25":60,
#
#     "26":60,
#
#     "27":60,
#
#     "28":60,
#
#     "29":60,
#
#     "30":60,
#
#     "31":45,
#
#     "32":60,
#
#     "33":60,
#
#     "34":60,
#
#     "35":60,
#
#     "36":60,
#
#     "37":60,
#
#     "38":60,
#
#     "39":45,
#
#     "40":45,
#
#     "41":60,
#
#     "42":60,
#
#     "43":60,
#
#     "44":60,
#
#     "45":60,
#
#     "46":60,
#
#     "47":45,
#
#     "48":45,
#
#     "49":60,
#
#     "50":60,
#
#     "51":80,
#
#     "52":60,
#
#     "53":60,
#
#     "54":30,
#
#     "55":60,
#
#     "56":60,
#
#     "57":45,
#
#     "58":20,
#
#     "59":45,
#
#     "60":210,
#
#     "61":160,
#
#     "62":160,
#
#     "63":45,
#
#     "64":20,
#
#     "65":180,
#
#     "66":150,
#
#     "67":150,
#
#     "68":20,
#
#     "69":300,
#
#     "70":150,
#
#     "71":60,
#
#     "72":90,
#
#     "73":150,
#
#     "74":45,
#
#     "75":90,
#
#     "76":45,
#
#     "77":45,
#
#     "78":120,
#
#     "79":270,
#
#     "80":30,
#
#     "81":45,
#
#     "82":30,
#
#     "83":120,
#
#     "84":45,
#
#     "85":30,
#
#     "86":45,
#
#     "87":120,
#
#     "88":45,
#
#     "89":20,
#
#     "90":180,
#
#     "91":45,
#
#     "92":30,
#
#     "93":15,
#
#     "94":20,
#
#     "95":20,
#
#     "96":30,
#
#     "97":25,
#
#     "98":30,
#
#     "99":90,
#
#     "100":20,
#
#     "101":90,
#
#     "102":90,
#
#     "103":90,
#
#     "104":30,
#
#     "105":30,
#
#     "106":180,
#
#     "107":30,
#
#     "108":90,
#
#     "109":210,
#
#     "110":60,
#
#     "111":45,
#
#     "112":15,
#
#     "113":45,
#
#     "114":60,
#
#     "115":60,
#
#     "116":60,
#
#     "117":60,
#
#     "118":60,
#
#     "119":60,
#
#     "120":30,
#
#     "121":45,
#
#     "122":60,
#
#     "123":60,
#
#     "124":60,
#
#     "125":60,
#
#     "126":60,
#
#     "127":60,
#
#     "128":90,
#
#     "129":60,
#
#     "130":60,
#
#     "131":60,
#
#     "132":60,
#
#     "133":60,
#
#     "134":60,
#
#     "135":20,
#
#     "136":45,
#
#     "137":45,
#
#     "138":45,
#
#     "139":20,
#
#     "140":60,
#
#     "141":60,
#
#     "142":45,
#
#     "143":45,
#
#     "144":60,
#
#     "145":45,
#
#     "146":60,
#
#     "147":60,
#
#     "148":30,
#
#     "149":60,
#
#     "150":60,
#
#     "151":60,
#
#     "152":60,
#
#     "153":30,
#
#     "154":60,
#
#     "155":60,
#
#     "156":60,
#
#     "157":60,
#
#     "158":60,
#
#     "159":30,
#
#     "160":30,
#
#     "161":45,
#
#     "162":45,
#
#     "163":45,
#
#     "164":60,
#
#     "165":60,
#
#     "166":60,
#
#     "167":75,
#
#     "168":75
#
#   },
#
#   "Pulse":{
#
#     "0":110,
#
#     "1":117,
#
#     "2":103,
#
#     "3":109,
#
#     "4":117,
#
#     "5":102,
#
#     "6":110,
#
#     "7":104,
#
#     "8":109,
#
#     "9":98,
#
#     "10":103,
#
#     "11":100,
#
#     "12":106,
#
#     "13":104,
#
#     "14":98,
#
#     "15":98,
#
#     "16":100,
#
#     "17":90,
#
#     "18":103,
#
#     "19":97,
#
#     "20":108,
#
#     "21":100,
#
#     "22":130,
#
#     "23":105,
#
#     "24":102,
#
#     "25":100,
#
#     "26":92,
#
#     "27":103,
#
#     "28":100,
#
#     "29":102,
#
#     "30":92,
#
#     "31":90,
#
#     "32":101,
#
#     "33":93,
#
#     "34":107,
#
#     "35":114,
#
#     "36":102,
#
#     "37":100,
#
#     "38":100,
#
#     "39":104,
#
#     "40":90,
#
#     "41":98,
#
#     "42":100,
#
#     "43":111,
#
#     "44":111,
#
#     "45":99,
#
#     "46":109,
#
#     "47":111,
#
#     "48":108,
#
#     "49":111,
#
#     "50":107,
#
#     "51":123,
#
#     "52":106,
#
#     "53":118,
#
#     "54":136,
#
#     "55":121,
#
#     "56":118,
#
#     "57":115,
#
#     "58":153,
#
#     "59":123,
#
#     "60":108,
#
#     "61":110,
#
#     "62":109,
#
#     "63":118,
#
#     "64":110,
#
#     "65":90,
#
#     "66":105,
#
#     "67":107,
#
#     "68":106,
#
#     "69":108,
#
#     "70":97,
#
#     "71":109,
#
#     "72":100,
#
#     "73":97,
#
#     "74":114,
#
#     "75":98,
#
#     "76":105,
#
#     "77":110,
#
#     "78":100,
#
#     "79":100,
#
#     "80":159,
#
#     "81":149,
#
#     "82":103,
#
#     "83":100,
#
#     "84":100,
#
#     "85":151,
#
#     "86":102,
#
#     "87":100,
#
#     "88":129,
#
#     "89":83,
#
#     "90":101,
#
#     "91":107,
#
#     "92":90,
#
#     "93":80,
#
#     "94":150,
#
#     "95":151,
#
#     "96":95,
#
#     "97":152,
#
#     "98":109,
#
#     "99":93,
#
#     "100":95,
#
#     "101":90,
#
#     "102":90,
#
#     "103":90,
#
#     "104":92,
#
#     "105":93,
#
#     "106":90,
#
#     "107":90,
#
#     "108":90,
#
#     "109":137,
#
#     "110":102,
#
#     "111":107,
#
#     "112":124,
#
#     "113":100,
#
#     "114":108,
#
#     "115":108,
#
#     "116":116,
#
#     "117":97,
#
#     "118":105,
#
#     "119":103,
#
#     "120":112,
#
#     "121":100,
#
#     "122":119,
#
#     "123":107,
#
#     "124":111,
#
#     "125":98,
#
#     "126":97,
#
#     "127":109,
#
#     "128":99,
#
#     "129":114,
#
#     "130":104,
#
#     "131":107,
#
#     "132":103,
#
#     "133":106,
#
#     "134":103,
#
#     "135":136,
#
#     "136":117,
#
#     "137":115,
#
#     "138":113,
#
#     "139":141,
#
#     "140":108,
#
#     "141":97,
#
#     "142":100,
#
#     "143":122,
#
#     "144":136,
#
#     "145":106,
#
#     "146":107,
#
#     "147":112,
#
#     "148":103,
#
#     "149":110,
#
#     "150":106,
#
#     "151":109,
#
#     "152":109,
#
#     "153":150,
#
#     "154":105,
#
#     "155":111,
#
#     "156":97,
#
#     "157":100,
#
#     "158":114,
#
#     "159":80,
#
#     "160":85,
#
#     "161":90,
#
#     "162":95,
#
#     "163":100,
#
#     "164":105,
#
#     "165":110,
#
#     "166":115,
#
#     "167":120,
#
#     "168":125
#
#   },
#
#   "Maxpulse":{
#
#     "0":130,
#
#     "1":145,
#
#     "2":135,
#
#     "3":175,
#
#     "4":148,
#
#     "5":127,
#
#     "6":136,
#
#     "7":134,
#
#     "8":133,
#
#     "9":124,
#
#     "10":147,
#
#     "11":120,
#
#     "12":128,
#
#     "13":132,
#
#     "14":123,
#
#     "15":120,
#
#     "16":120,
#
#     "17":112,
#
#     "18":123,
#
#     "19":125,
#
#     "20":131,
#
#     "21":119,
#
#     "22":101,
#
#     "23":132,
#
#     "24":126,
#
#     "25":120,
#
#     "26":118,
#
#     "27":132,
#
#     "28":132,
#
#     "29":129,
#
#     "30":115,
#
#     "31":112,
#
#     "32":124,
#
#     "33":113,
#
#     "34":136,
#
#     "35":140,
#
#     "36":127,
#
#     "37":120,
#
#     "38":120,
#
#     "39":129,
#
#     "40":112,
#
#     "41":126,
#
#     "42":122,
#
#     "43":138,
#
#     "44":131,
#
#     "45":119,
#
#     "46":153,
#
#     "47":136,
#
#     "48":129,
#
#     "49":139,
#
#     "50":136,
#
#     "51":146,
#
#     "52":130,
#
#     "53":151,
#
#     "54":175,
#
#     "55":146,
#
#     "56":121,
#
#     "57":144,
#
#     "58":172,
#
#     "59":152,
#
#     "60":160,
#
#     "61":137,
#
#     "62":135,
#
#     "63":141,
#
#     "64":130,
#
#     "65":130,
#
#     "66":135,
#
#     "67":130,
#
#     "68":136,
#
#     "69":143,
#
#     "70":129,
#
#     "71":153,
#
#     "72":127,
#
#     "73":127,
#
#     "74":146,
#
#     "75":125,
#
#     "76":134,
#
#     "77":141,
#
#     "78":130,
#
#     "79":131,
#
#     "80":182,
#
#     "81":169,
#
#     "82":139,
#
#     "83":130,
#
#     "84":120,
#
#     "85":170,
#
#     "86":136,
#
#     "87":157,
#
#     "88":103,
#
#     "89":107,
#
#     "90":127,
#
#     "91":137,
#
#     "92":107,
#
#     "93":100,
#
#     "94":171,
#
#     "95":168,
#
#     "96":128,
#
#     "97":168,
#
#     "98":131,
#
#     "99":124,
#
#     "100":112,
#
#     "101":110,
#
#     "102":100,
#
#     "103":100,
#
#     "104":108,
#
#     "105":128,
#
#     "106":120,
#
#     "107":120,
#
#     "108":120,
#
#     "109":184,
#
#     "110":124,
#
#     "111":124,
#
#     "112":139,
#
#     "113":120,
#
#     "114":131,
#
#     "115":151,
#
#     "116":141,
#
#     "117":122,
#
#     "118":125,
#
#     "119":124,
#
#     "120":137,
#
#     "121":120,
#
#     "122":169,
#
#     "123":127,
#
#     "124":151,
#
#     "125":122,
#
#     "126":124,
#
#     "127":127,
#
#     "128":125,
#
#     "129":151,
#
#     "130":134,
#
#     "131":138,
#
#     "132":133,
#
#     "133":132,
#
#     "134":136,
#
#     "135":156,
#
#     "136":143,
#
#     "137":137,
#
#     "138":138,
#
#     "139":162,
#
#     "140":135,
#
#     "141":127,
#
#     "142":120,
#
#     "143":149,
#
#     "144":170,
#
#     "145":126,
#
#     "146":136,
#
#     "147":146,
#
#     "148":127,
#
#     "149":150,
#
#     "150":134,
#
#     "151":129,
#
#     "152":138,
#
#     "153":167,
#
#     "154":128,
#
#     "155":151,
#
#     "156":131,
#
#     "157":120,
#
#     "158":150,
#
#     "159":120,
#
#     "160":120,
#
#     "161":130,
#
#     "162":130,
#
#     "163":140,
#
#     "164":140,
#
#     "165":145,
#
#     "166":145,
#
#     "167":150,
#
#     "168":150
#
#   },
#
#   "Calories":{
#
#     "0":409.1,
#
#     "1":479.0,
#
#     "2":340.0,
#
#     "3":282.4,
#
#     "4":406.0,
#
#     "5":300.5,
#
#     "6":374.0,
#
#     "7":253.3,
#
#     "8":195.1,
#
#     "9":269.0,
#
#     "10":329.3,
#
#     "11":250.7,
#
#     "12":345.3,
#
#     "13":379.3,
#
#     "14":275.0,
#
#     "15":215.2,
#
#     "16":300.0,
#
#     "17":null,
#
#     "18":323.0,
#
#     "19":243.0,
#
#     "20":364.2,
#
#     "21":282.0,
#
#     "22":300.0,
#
#     "23":246.0,
#
#     "24":334.5,
#
#     "25":250.0,
#
#     "26":241.0,
#
#     "27":null,
#
#     "28":280.0,
#
#     "29":380.3,
#
#     "30":243.0,
#
#     "31":180.1,
#
#     "32":299.0,
#
#     "33":223.0,
#
#     "34":361.0,
#
#     "35":415.0,
#
#     "36":300.5,
#
#     "37":300.1,
#
#     "38":300.0,
#
#     "39":266.0,
#
#     "40":180.1,
#
#     "41":286.0,
#
#     "42":329.4,
#
#     "43":400.0,
#
#     "44":397.0,
#
#     "45":273.0,
#
#     "46":387.6,
#
#     "47":300.0,
#
#     "48":298.0,
#
#     "49":397.6,
#
#     "50":380.2,
#
#     "51":643.1,
#
#     "52":263.0,
#
#     "53":486.0,
#
#     "54":238.0,
#
#     "55":450.7,
#
#     "56":413.0,
#
#     "57":305.0,
#
#     "58":226.4,
#
#     "59":321.0,
#
#     "60":1376.0,
#
#     "61":1034.4,
#
#     "62":853.0,
#
#     "63":341.0,
#
#     "64":131.4,
#
#     "65":800.4,
#
#     "66":873.4,
#
#     "67":816.0,
#
#     "68":110.4,
#
#     "69":1500.2,
#
#     "70":1115.0,
#
#     "71":387.6,
#
#     "72":700.0,
#
#     "73":953.2,
#
#     "74":304.0,
#
#     "75":563.2,
#
#     "76":251.0,
#
#     "77":300.0,
#
#     "78":500.4,
#
#     "79":1729.0,
#
#     "80":319.2,
#
#     "81":344.0,
#
#     "82":151.1,
#
#     "83":500.0,
#
#     "84":225.3,
#
#     "85":300.1,
#
#     "86":234.0,
#
#     "87":1000.1,
#
#     "88":242.0,
#
#     "89":50.3,
#
#     "90":600.1,
#
#     "91":null,
#
#     "92":105.3,
#
#     "93":50.5,
#
#     "94":127.4,
#
#     "95":229.4,
#
#     "96":128.2,
#
#     "97":244.2,
#
#     "98":188.2,
#
#     "99":604.1,
#
#     "100":77.7,
#
#     "101":500.0,
#
#     "102":500.0,
#
#     "103":500.4,
#
#     "104":92.7,
#
#     "105":124.0,
#
#     "106":800.3,
#
#     "107":86.2,
#
#     "108":500.3,
#
#     "109":1860.4,
#
#     "110":325.2,
#
#     "111":275.0,
#
#     "112":124.2,
#
#     "113":225.3,
#
#     "114":367.6,
#
#     "115":351.7,
#
#     "116":443.0,
#
#     "117":277.4,
#
#     "118":null,
#
#     "119":332.7,
#
#     "120":193.9,
#
#     "121":100.7,
#
#     "122":336.7,
#
#     "123":344.9,
#
#     "124":368.5,
#
#     "125":271.0,
#
#     "126":275.3,
#
#     "127":382.0,
#
#     "128":466.4,
#
#     "129":384.0,
#
#     "130":342.5,
#
#     "131":357.5,
#
#     "132":335.0,
#
#     "133":327.5,
#
#     "134":339.0,
#
#     "135":189.0,
#
#     "136":317.7,
#
#     "137":318.0,
#
#     "138":308.0,
#
#     "139":222.4,
#
#     "140":390.0,
#
#     "141":null,
#
#     "142":250.4,
#
#     "143":335.4,
#
#     "144":470.2,
#
#     "145":270.8,
#
#     "146":400.0,
#
#     "147":361.9,
#
#     "148":185.0,
#
#     "149":409.4,
#
#     "150":343.0,
#
#     "151":353.2,
#
#     "152":374.0,
#
#     "153":275.8,
#
#     "154":328.0,
#
#     "155":368.5,
#
#     "156":270.4,
#
#     "157":270.4,
#
#     "158":382.8,
#
#     "159":240.9,
#
#     "160":250.4,
#
#     "161":260.4,
#
#     "162":270.0,
#
#     "163":280.9,
#
#     "164":290.8,
#
#     "165":300.4,
#
#     "166":310.2,
#
#     "167":320.4,
#
#     "168":330.4
#
#   }
#
# }
# error is	 division by zero
# Done

# %%
def double(var):
	if var<=0:
		raise Exception("IllegalValue Exception")
	return var*2

def fun():
	try:
		print(double(-1))
	except Exception as e:
		print("error is\t",e.__str__())
	print("Done")
fun()
# Out:
# error is	 IllegalValue Exception
# Done

# %%
def double(var):
	if var<=0:
		raise Exception("IllegalValue Exception")  #not compulsory to handle exception
	return var*2

def fun():
	print(double(4))
	print("Done")
fun()
# Out:
# 8
# Done

# %% [markdown]
# ### User Defined Exception

# %%
class IllegalValue(Exception):
	pass

def double(var):
	if var<=0:
		raise IllegalValue("Number cannot be negative or zero")
		# raise IllegalValue()
	return var*2

def fun():
	try:
		print(double(-4))
	except Exception as e:
		print("error is\t",e.__str__())
	print("Done")
fun()
# Out:
# error is	 Number cannot be negative or zero
# Done

# %%
class IllegalValue(Exception):
    def __init__(self, msg):
        super().__init__(msg)

def double(var):
    if var <= 0:
        raise IllegalValue("Number cannot be negative or zero")
    return var * 2

def fun():
    try:
        print(double(-4))
    except Exception as e:
        print("error is\t", e.__str__())
    print("Done")

fun()
# Out:
# error is	 Number cannot be negative or zero
# Done

# %% [markdown]
# # File Handling

# %%
from os import path

print("File Exists\t",path.exists("web.xml"))
print("Directory Exists\t",path.exists("eg"))
# Out:
# File Exists	 True
# Directory Exists	 True

# %%
import os

os.rename("iris.csv","temp.txt")
print("Done")
# Out:
# Done

# %%
import shutil

#  Python allows you to quickly create zip/tar archives.
# Following command will zip entire directory

# here "myzip.zip" will be created of the current working directory (. is given) and that zip file will be stored in the current working directory itself.

shutil.make_archive("myzip","zip","eg")  #eg folder by be archieved
print("Done")
# Out:
# Done

# %%
# we can define which specific file to include under archive. 


from zipfile import ZipFile

with ZipFile("temp.zip","w") as newzip:
		newzip.write("Book1.csv")
		newzip.write("ForPandas.xls")

# %%
newzip=ZipFile("temp2.zip","w")
try:
    newzip.write("Book1.csv")
    newzip.write("ForPandas.xls")
finally:
    newzip.close()

# %%
# how to read from a file


with open("details.json","r") as f:
    data=f.read()
    print(data)

print("Done")
# Out:
# [
# 	{
# 		"Name": "Sachin",
# 		"Age":  40,
# 		"Address": "Mumbai"
# 	},
# 	{
# 		"Name": "Rahul",
# 		"Age": 45,
# 		"Address": "Banglore"
# 	}
# ]
# Done

# %%
# how to write inside a file
with open("myfile.txt","w") as f:
	print("enter messages, stop to quit\n")
	while True:
		str=input()
		if str=="stop":
			break
		f.writelines(str+"\n")

print("Done")
# Out:
# enter messages, stop to quit
#  hello
#  HOw are you
#  stop
# Done

# %%
# how to write inside a file and read also using "w+" mode ( write and read mode)


with open("myfile.txt","w+") as f:
    print("enter messages, stop to quit\n")
    while True:
        str=input()
        if str=="stop":
            break
        f.writelines(str+"\n")
    f.seek(0, 0)  # place the file pointer at the beginning
    data=f.read()
    print(data)
print("Done")
# Out:
# enter messages, stop to quit
#  I am fine
#  stop
# I am fine
#
# Done

# %%
# how to append and read a file using "a+" mode

with open("myfile.txt","a+") as f:
    print("enter messages, stop to quit\n")
    while True:
        str=input()
        if str=="stop":
            break
        f.writelines(str+"\n")

    f.seek(0, 0)  # place the file pointer at the beginning
    data=f.read()
    print(data)

print("Done")
# Out:
# enter messages, stop to quit
#  hi
#  hello there
#  stop
# I am fine
# hi
# hello there
#
# Done

# %%
# how to read and write a file using "r+" mode

with open("myfile.txt", "r+") as f:
		data=f.read()
		print(data)
		f.seek(f.tell())  # to place the file pointer at the end
		
		print("enter message\n")
		str = input()
		f.write(str)
		print("lets read again")
		f.seek(0, 0)  # place the file pointer at the beginning
		data=f.read()
		print(data)

print("Done")
# Out:
# I am fine
# hi
# hello there
#
# enter message
#  bonjour
# lets read again
# I am fine
# hi
# hello there
# bonjour
# Done

# %%
# file copy program

with open("temp.txt","r") as f1,open("temp1.txt","w") as f2:
    data=f1.read()
    f2.write(data)
print("done with copy")
# Out:
# done with copy

# %% [markdown]
# ## With

# %% [markdown]
# The with statement in Python is used for resource management and exception handling. You’d most likely find it when working with file streams.
#
# The code block below shows the try-finally approach to file stream resource management.

# %%
file = open('file-path', 'w') 
try: 
    file.write('Lorem ipsum') 
finally: 
    file.close()

# %%
#Normally, you’d want to use this method for writing to a file, but the with statement offers a cleaner approach:

with open('file-path', 'w') as file: 
    file.write('Lorem ipsum') 
    
#The with statement simplifies our write process to just two lines.

# %% [markdown]
# In order to be used with the "with" statement , a class must follow  Python’s "context management protocol" which says that class must have "__enter__" and "__exit__" methods.
#
# __enter__ method is called at the start of with block and __exit__ method is called at the end.

# %%
class MyReader:
    def __init__(self, filename,mode):
       self.filename=filename
       self.mode=mode
    def __enter__(self):
        print("in __enter__")
        # logic to open "filename" in "mode" mode  
        return self
    def __exit__(self, exception_type, exception_value, traceback):
        print("in __exit__\t",exception_value)
        self.close()
    def close(self):
        print("closing the stream\n")
    def read(self):
        if len(self.filename)<9:
            raise Exception("not able to read the file")
        print("successfully read the file")

print("before with")
with MyReader("af.txt","r") as m:
    # exception successfully pass to __exit__
    print("before read")
    m.read()
    print("after read")
print("done")
# Out:
# before with
# in __enter__
# before read
# in __exit__	 not able to read the file
# closing the stream
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[39], line 23
#      20 with MyReader("af.txt","r") as m:
#      21     # exception successfully pass to __exit__
#      22     print("before read")
# ---> 23     m.read()
#      24     print("after read")
#      25 print("done")
#
# Cell In[39], line 16, in MyReader.read(self)
#      14 def read(self):
#      15     if len(self.filename)<9:
# ---> 16         raise Exception("not able to read the file")
#      17     print("successfully read the file")
#
# Exception: not able to read the file

# %% [markdown]
# # Operator Overloading

# %%
class First:
    def __init__(self,num1):
        self.num1=num1
class Second:
    def __init__(self,num2):
        self.num2=num2

f1=First(100)
f2=Second(200)

print(f1.num1,"\t",f2.num2)
print(f1.num1+f2.num2)
# Out:
# 100 	 200
# 300

# %%
class First:
    def __init__(self,num1):
        self.num1=num1
class Second:
    def __init__(self,num2):
        self.num2=num2

f1=First(100)
f2=Second(200)

print(f1.num1,"\t",f2.num2)
#  print(f1+f2)             #    TypeError: unsupported operand type(s) for +: 'First' and 'Second'
# Out:
# 100 	 200

# %%
class First:
    def __init__(self,num1):
        self.num1=num1
    def __add__(self,obj):
        print("inside __add__ method of First")
        return self.num1+obj.num2

class Second:
    def __init__(self,num2):
        self.num2=num2

f1=First(100)
f2=Second(200)

print(f1.num1,"\t",f2.num2)
print(f1+f2)     # f1.__add__(f2)      
#print(f2+f1)   # won't work
# Out:
# 100 	 200
# inside __add__ method of First
# 300

# %%
class First:
    def __init__(self,num1):
        self.num1=num1
    def __add__(self,temp):
        return self.num1+temp

f1=First(50)
print(f1+100)
# Out:
# 150

# %%
class First:
    def __init__(self,num1):
        self.num1=num1
    def __add__(self,temp):
        return self.num1+temp

f1=First(50)
print(f1+100)
# Out:
# 150

# %%
a = 2
b = 3
a.__add__(b)
# Out:
# 5

# %%
# sort the list in ascending order

class Student:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def __str__(self):
        return  self.name+' '+str(self.age)
    def getname(self):
        return self.name
    def getage(self):
        return self.age

s1 = Student("Sachin",23)
s2 = Student("Rahul",32)
s3 = Student("Anand",34)

mylist = [s1,s2,s3]
print(mylist)

for i in mylist:
    print(i)

mylist.sort(key=Student.getname)     # strategy of name based on which sort() method  will sort the object
print("After sorting")
for i in mylist:
    print(i)
# Out:
# [<__main__.Student object at 0x000002152BCAD6A0>, <__main__.Student object at 0x000002152BCEDA00>, <__main__.Student object at 0x000002152BCECE30>]
# Sachin 23
# Rahul 32
# Anand 34
# After sorting
# Anand 34
# Rahul 32
# Sachin 23

# %%
class First:
    def __init__(self,num):
        self.num = num


    
    def __add__(self,ss):
        return self.num+ss.num


f1 = First(1)
f2 = First(2)

f1+f2  
f1.__add__(f2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 9
#       6 f1 = First(1)
#       7 f2 = First(2)
# ----> 9 f1+f2
#
# TypeError: unsupported operand type(s) for +: 'First' and 'First'
